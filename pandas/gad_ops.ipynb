# %%
import pandas as pd

# %%
df = pd.read_csv('/home/rijumone/output.csv')

# %%
df
# Out:
#        Ad group ID                        Ad group Ad group state  All conv.  \
# 0     106803097191  Flavors / Cartridges / Bottles        enabled          1
# 1     106803096871                   Brand - Exact        enabled          1
# 2     106803096871                   Brand - Exact        enabled          1
# 3     105033971660                   Brand - Exact        enabled          1
# 4     105033971660                   Brand - Exact        enabled          1
# ...            ...                             ...            ...        ...
# 7178  106803096871                   Brand - Exact        enabled          1
# 7179  105033971660                   Brand - Exact        enabled          1
# 7180  105033972220                    Subscription        enabled          1
# 7181  106803096871                   Brand - Exact        enabled          1
# 7182         Total                              --             --       7721
#
#       All conv. value  Campaign ID  \
# ...

# %%
df.where(df['Conversion name'] == 'Purchase - Jump')
# Out:
#        Ad group ID                        Ad group Ad group state  All conv.  \
# 0     106803097191  Flavors / Cartridges / Bottles        enabled        1.0
# 1              NaN                             NaN            NaN        NaN
# 2              NaN                             NaN            NaN        NaN
# 3              NaN                             NaN            NaN        NaN
# 4              NaN                             NaN            NaN        NaN
# ...            ...                             ...            ...        ...
# 7178           NaN                             NaN            NaN        NaN
# 7179           NaN                             NaN            NaN        NaN
# 7180  105033972220                    Subscription        enabled        1.0
# 7181           NaN                             NaN            NaN        NaN
# 7182           NaN                             NaN            NaN        NaN
#
#       All conv. value  Campaign ID  \
# ...

# %%
df
# Out:
#        Ad group ID                        Ad group Ad group state  All conv.  \
# 0     106803097191  Flavors / Cartridges / Bottles        enabled        1.0
# 1              NaN                             NaN            NaN        NaN
# 2              NaN                             NaN            NaN        NaN
# 3              NaN                             NaN            NaN        NaN
# 4              NaN                             NaN            NaN        NaN
# ...            ...                             ...            ...        ...
# 7178           NaN                             NaN            NaN        NaN
# 7179           NaN                             NaN            NaN        NaN
# 7180  105033972220                    Subscription        enabled        1.0
# 7181           NaN                             NaN            NaN        NaN
# 7182           NaN                             NaN            NaN        NaN
#
#       All conv. value  Campaign ID  \
# ...
