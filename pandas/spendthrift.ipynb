# %%
import pandas as pd

# %%
df_1_year = pd.read_csv('47536443_1574755217201_dropped_nulls_dropped_ref_num.csv')

# %%
df_1_year
# Out:
#      Unnamed: 0      Date                                          Narration  \
# 0             0  01/11/18              IB BILLPAY DR-HDFCZF-552365XXXXXX7501
# 1             1  08/11/18  UPI-1311830225-AKSHAYTHEGENIUS@OKSBI-PAY-83121...
# 2             2  13/11/18               POS 416021XXXXXX1070 PAYTM POS DEBIT
# 3             3  15/11/18  50200002753536   6580863-90412768616-TS-DG-AXI...
# 4             4  16/11/18  UPI-50100102272932-SUMITAS.DESIGNER@OKHDFCBANK...
# ..          ...       ...                                                ...
# 562         710  30/10/19              LQRXK5UFA5ZKNNGW/PAYUDEALSKARTONLINES
# 563         711  30/10/19              LQRXK54MAF72FOO2/PAYUDEALSKARTONLINES
# 564         712  30/10/19    POS 416021XXXXXX1070 LAKE FOREST WINE POS DEBIT
# 565         713  30/10/19    POS 416021XXXXXX1070 LAKE FOREST WINE POS DEBIT
# 566         714  30/10/19    POS 416021XXXXXX1070 LAKE FOREST WINE POS DEBIT
#
#      Value Dt  Withdrawal Amt.
# ...

# %%
for row in df_1_year.itertuples():
    print(row)
# Out:
# Pandas(Index=0, _1=0, Date='01/11/18', Narration='IB BILLPAY DR-HDFCZF-552365XXXXXX7501', _4='01/11/18', _5=58984.0)
# Pandas(Index=1, _1=1, Date='08/11/18', Narration='UPI-1311830225-AKSHAYTHEGENIUS@OKSBI-PAY-831217217539-SPLITWISE SETTLED', _4='08/11/18', _5=7707.0)
# Pandas(Index=2, _1=2, Date='13/11/18', Narration='POS 416021XXXXXX1070 PAYTM POS DEBIT', _4='13/11/18', _5=50.0)
# Pandas(Index=3, _1=3, Date='15/11/18', Narration='50200002753536   6580863-90412768616-TS-DG-AXIS-SIP', _4='15/11/18', _5=500.0)
# Pandas(Index=4, _1=4, Date='16/11/18', Narration='UPI-50100102272932-SUMITAS.DESIGNER@OKHDFCBANK-PAY-832011687429-AJAY BIRTHDAY PARTY', _4='16/11/18', _5=1500.0)
# Pandas(Index=5, _1=7, Date='16/11/18', Narration='UPI-1000129101465-FRESHMENU@AXISBANK-PAY-832014035060-PAYMENT FOR FRESHMENU ORDER', _4='16/11/18', _5=183.0)
# Pandas(Index=6, _1=9, Date='16/11/18', Narration='POS 416021XXXXXX1070 AMAZON POS DEBIT', _4='16/11/18', _5=33499.0)
# ...

# %%
df_1_year.loc[:, 'Date']
# Out:
# 0      01/11/18
# 1      08/11/18
# 2      13/11/18
# 3      15/11/18
# 4      16/11/18
#          ...
# 562    30/10/19
# 563    30/10/19
# 564    30/10/19
# 565    30/10/19
# 566    30/10/19
# Name: Date, Length: 567, dtype: object

# %%
df_1_year.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Narration', 'Value Dt', 'Withdrawal Amt.'], dtype='object')

# %%
df_1_year.loc[:, 'Value Dt'].equals(df_1_year.loc[:, 'Date'])
# Out:
# False

# %%
df_1_year.loc[:, 'Value Dt'].eq(df_1_year.loc[:, 'Date'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 562    True
# 563    True
# 564    True
# 565    True
# 566    True
# Length: 567, dtype: bool

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_1_year)
# Out:
#      Unnamed: 0       Date                                          Narration  \
# 0             0 2018-11-01              IB BILLPAY DR-HDFCZF-552365XXXXXX7501
# 1             1 2018-11-08  UPI-1311830225-AKSHAYTHEGENIUS@OKSBI-PAY-83121...
# 2             2 2018-11-13               POS 416021XXXXXX1070 PAYTM POS DEBIT
# 3             3 2018-11-15  50200002753536   6580863-90412768616-TS-DG-AXI...
# 4             4 2018-11-16  UPI-50100102272932-SUMITAS.DESIGNER@OKHDFCBANK...
# 5             7 2018-11-16  UPI-1000129101465-FRESHMENU@AXISBANK-PAY-83201...
# 6             9 2018-11-16              POS 416021XXXXXX1070 AMAZON POS DEBIT
# 7            10 2018-11-16  NEFT DR-UTIB0000312-ANGADBIR SINGH-NETBANK, MU...
# 8            11 2018-11-19    POS 416021XXXXXX1070 FUTURE RETAIL LT POS DEBIT
# 9            12 2018-12-03  NEFT DR-SBIN0004422-PPF ACCOUNT-SANDOZ - MUM-N...
# 10           13 2018-12-03              IB BILLPAY DR-HDFCZF-552365XXXXXX7501
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_1_year.loc[:, 'Value Dt'].eq(df_1_year.loc[:, 'Date']))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
# 41      True
# 42      True
# 43      True
# 44      True
# 45      True
# 46     False
# 47      True
# 48      True
# 49      True
# 50      True
# 51      True
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60     False
# 61     False
# 62      True
# 63      True
# 64      True
# 65      True
# ...

# %%
for column in df_1_year.columns:
    print(df_1_year[column].dtype)
# Out:
# int64
# object
# object
# object
# float64

# %%
print(df_1_year['Value Dt'].dtype)
# Out:
# datetime64[ns]

# %%
df_1_year['Date'] = pd.to_datetime(df_1_year['Date'], format='%d/%m/%y')

# %%
df_1_year['Value Dt'] = pd.to_datetime(df_1_year['Value Dt'], format='%d/%m/%y')

# %%
for index, row in df_1_year.iterrows():
    if row['Date'] != row['Value Dt']:
        delta = row['Value Dt'] - row['Date']
        if delta.days > 1:
            print('Delta:{}, Narration: {}, Date: {}, Value Dt: {}'.format(
                delta,
                row['Narration'], 
                row['Date'], 
                row['Value Dt'],
            ))

# %%
# Here we realised that Value Dt is at max one day greater than Date
# if not the same day.
# Hence, dropping column Value Dt

# %%
df_1_year = df_1_year.drop(columns='Value Dt')

# %%
df_1_year.to_csv('47536443_1574755217201_dropped_nulls_dropped_ref_num_dropped_value_dt.csv')

# %%
df_1_year = pd.read_csv('47536443_1574755217201_dropped_nulls_dropped_ref_num_dropped_value_dt.csv')

# %%
df_1_year
# Out:
#      Unnamed: 0  Unnamed: 0.1        Date  \
# 0             0             0  2018-11-01
# 1             1             1  2018-11-08
# 2             2             2  2018-11-13
# 3             3             3  2018-11-15
# 4             4             4  2018-11-16
# ..          ...           ...         ...
# 562         562           710  2019-10-30
# 563         563           711  2019-10-30
# 564         564           712  2019-10-30
# 565         565           713  2019-10-30
# 566         566           714  2019-10-30
#
#                                              Narration  Withdrawal Amt.
# 0                IB BILLPAY DR-HDFCZF-552365XXXXXX7501         58984.00
# 1    UPI-1311830225-AKSHAYTHEGENIUS@OKSBI-PAY-83121...          7707.00
# 2                 POS 416021XXXXXX1070 PAYTM POS DEBIT            50.00
# 3    50200002753536   6580863-90412768616-TS-DG-AXI...           500.00
# 4    UPI-50100102272932-SUMITAS.DESIGNER@OKHDFCBANK...          1500.00
# ...
